# %%
#
# Start Date 20260420
# Chapter 01 - From Loose Code to Local Package (chapter)
# Developing Python Packages (course)
# Data Scientist in Python (track)
# Resources: None
#

# %%
#
# Start Date YYYYMMDD
# Chapter 02 - Install Your Package from Anywhere (chapter)
# Developing Python Packages (course)
# Data Scientist in Python (track)
# Resources: None
#

# %%
#
# Start Date YYYYMMDD
# Chapter 03 - Increasing Your Package Quality (chapter)
# Developing Python Packages (course)
# Data Scientist in Python (track)
# Resources: None
#

# %%
#
# Start Date YYYYMMDD
# Chapter 04 - Rapid Package Development (chapter)
# Developing Python Packages (course)
# Data Scientist in Python (track)
# Resources: None
#
